# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
x1 = pd.read_csv("x1.csv")
x2 = pd.read_csv("x2.csv")
y1 = pd.read_csv("y1.csv")
y2 = pd.read_csv("y2.csv")

# %%
x1.head()
# Out:
#     1.3827   0.22592  0.13294  -1.0707  -1.0826  -1.0997   0.56249  -0.39981  \
# 0 -1.66400 -0.079993  0.29757 -1.87740 -0.86082  0.81922  0.098554  -1.12060
# 1  0.54314  0.636410  1.29420  2.02370 -0.45051  1.20380  1.437200  -1.31370
# 2 -1.23650 -0.436510  1.47790 -1.61900  0.34281 -1.85290 -0.511870   0.82982
# 3  0.35911  2.097900 -0.48545 -0.11176  1.24580 -0.12491 -0.630680  -0.59079
# 4  0.57235 -0.984640  1.14600  0.36912  1.49790 -0.45756 -0.831860   0.77346
#
#     0.22299   0.42888  ...  0.42526    1.8481   -1.3218  0.71849  1   1.0738  \
# 0  0.362990  1.688700  ... -0.66313  0.728130 -0.177990 -1.27420  1 -0.91968
# 1 -1.816700  1.306900  ...  1.54680 -1.136200 -0.099025 -0.52601  1  0.63598
# 2 -0.920060 -0.221190  ... -1.47390  2.030800  0.856240 -0.49353  1  1.10430
# 3  0.019867  0.007155  ... -0.28033 -1.412500  1.563400  1.83350  1  0.35216
# 4 -0.498410 -0.720190  ... -0.50826 -0.071624  1.221700 -0.15422  1 -1.01480
#
#    0.53867  -1.7281  0.37059  -0.69765
# 0 -0.76156  0.32066 -0.31124  -1.39040
# 1 -0.56695  0.18659  1.16690   1.57850
# 2 -0.22019  0.78291  0.59089  -0.72670
# 3  1.18780  0.69124 -0.85396  -0.67284
# 4  0.55937 -1.14280  0.49039  -2.45550
#
# [5 rows x 26 columns]

# %%
y1.head()
# Out:
#    -0.76734
# 0 -0.072655
# 1  0.045429
# 2 -1.169300
# 3  0.552800
# 4  1.098400

# %%
x1.shape
# Out:
# (49, 26)

# %%
y1.shape
# Out:
# (49, 1)

# %%
x2.shape
# Out:
# (49, 26)

# %%
x2.head()
# Out:
#     -1.4725  0.040221  -0.18403  -0.77526   -2.254   -1.2489  0.076201  \
# 0  1.068000   0.19718 -0.562430 -0.162000  1.23040  0.084049   0.80703
# 1  0.046897   2.28460 -1.864900  1.466400 -0.63959  0.005554  -0.22667
# 2  0.483440   1.46380 -0.013712 -0.037563  2.41740 -0.246470  -1.03580
# 3 -1.848600   1.27940 -0.211740  0.198340 -0.83718  2.486100   1.89740
# 4 -0.489180   0.20368  0.120580  0.955020 -0.10680  0.608710  -0.65594
#
#    0.57249  -0.66675  0.63484  ...  -0.48008  0.88803    2.5497  -0.79788  1  \
# 0 -0.88252   1.22520  0.37915  ...  -1.29660 -0.27845  0.895210 -0.089012  1
# 1 -1.94150  -0.51689  0.33673  ...  -0.43896  1.06600 -0.072292 -0.473980  1
# 2  0.56813  -0.70365 -2.16540  ...  -1.32600  0.81510 -0.811230  0.231450  1
# 3  0.86957  -0.71522  1.28400  ...   0.51365  0.15240 -0.340210 -1.307900  1
# 4  0.55625  -0.72119 -0.93480  ...  -0.53101 -0.24601  0.004671 -0.788750  1
#
#    -0.49989  0.27105  0.82444  0.02131  -0.42288
# 0   0.38247 -0.36754 -0.40374   1.3701  -0.38080
# 1  -0.70156  0.19032  0.91833   1.1515  -2.19500
# 2  -2.59760 -0.51483  1.34540  -1.7429   0.57277
# 3   0.17259 -0.61924  0.82814   1.0353   2.20130
# 4   2.01170  0.76708 -0.28105   1.0285   2.88280
#
# [5 rows x 26 columns]

# %%
from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression()
reg.fit(x1, y1)
# Out:
# LinearRegression()
